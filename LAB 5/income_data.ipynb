# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\bda\Desktop\261100660031\AML_LAB\Lab_5\income_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    income  happiness
# 0           1  3.862647   2.314489
# 1           2  4.979381   3.433490
# 2           3  4.923957   4.599373
# 3           4  3.214372   2.791114
# 4           5  7.196409   5.596398

# %%
df.shape
# Out:
# (498, 3)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'income', 'happiness'], dtype='str')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# income        float64
# happiness     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  498 non-null    int64
#  1   income      498 non-null    float64
#  2   happiness   498 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
df.describe()
# Out:
#        Unnamed: 0      income   happiness
# count  498.000000  498.000000  498.000000
# mean   249.500000    4.466902    3.392859
# std    143.904482    1.737527    1.432813
# min      1.000000    1.506275    0.266044
# 25%    125.250000    3.006256    2.265864
# 50%    249.500000    4.423710    3.472536
# 75%    373.750000    5.991913    4.502621
# max    498.000000    7.481521    6.863388

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# income        0
# happiness     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df[["income"]]
x
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
y = df["happiness"]

# %%
model = LinearRegression()
model.fit(x, y)

y_pred = model.predict(x)
y_pred
# Out:
# array([2.96152667, 3.75867986, 3.71911648, 2.49877145, 5.34125092,
#        2.86658506, 3.54106017, 3.41513166, 2.43256991, 3.51635969,
#        3.51130944, 2.18383624, 5.28633585, 5.53415794, 1.7159689 ,
#        2.03106825, 1.88518187, 1.90899797, 3.5989963 , 1.6278348 ,
#        5.42298877, 2.72287448, 1.9379753 , 2.73317421, 3.93558   ,
#        4.98118583, 2.98848252, 1.83968425, 1.9035411 , 2.02424619,
#        5.15343384, 1.52887726, 2.76620668, 5.07718449, 1.68231885,
#        3.9334414 , 1.80546213, 5.25541848, 3.19567934, 1.6008601 ,
#        3.81748253, 3.04685917, 2.39218744, 2.83320231, 2.9092617 ,
#        4.02945835, 3.91339326, 3.94556523, 5.27358764, 2.64842401,
#        1.81280411, 4.03775389, 4.64826679, 4.11807734, 3.08396537,
#        4.85143061, 4.50807707, 5.16472447, 5.34027157, 2.17252896,
#        5.1696974 , 3.53797301, 4.75012017, 4.60620474, 4.54015955,
#        4.11940272, 1.3389494 , 1.40383556, 4.13027356, 3.09090289,
# ...

# %%
print("Intercept : ", model.intercept_)
print("Slope : ", model.coef_[0])
# Out:
# Intercept :  0.20427039623160237
# Slope :  0.7138255122719708

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

print("MAE       : ", mean_absolute_error(y, y_pred))
print("MSE       : ", mean_squared_error(y, y_pred))
print("RMSE      : ", np.sqrt(mean_squared_error(y, y_pred)))
print("R-squared : ", r2_score(y, y_pred))
# Out:
# MAE       :  0.574598873075896
# MSE       :  0.5135973650248548
# RMSE      :  0.716657076309761
# R-squared :  0.7493217544889172

# %%
new_data = pd.DataFrame({'income' : [6.225]})
predicted_mark = model.predict(new_data)

# %%
print("predicted mark : ", predicted_mark[0])
# Out:
# predicted mark :  4.64783421012462

# %%
plt.scatter(x, y, color = "blue", label = "Actual Data")
plt.plot(x, y_pred, color = "red", label = "Regression Line")

plt.xlabel("Income")
plt.ylabel("Happiness")
plt.title("Income Vs. Happiness")
#plt.grid(True)
plt.legend()
plt.show()
